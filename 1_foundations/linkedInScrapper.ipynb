# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/ab_profile.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# 7813534440 (Mobile)
# araiz.baqi@gmail.com
# www.linkedin.com/in/araizbaqi
# (LinkedIn)
# Top Skills
# Computer Proficiency
# Leadership
# Network Proficiency
# Languages
# Hindi (Full Professional)
# Urdu (Native or Bilingual)
# Introductory Italian (Elementary)
# English (Full Professional)
# Certifications
# High School degree
# Publications
# Soccer Analyst / Writer
# Araiz Baqi
# Senior Software Developer
# New York City Metropolitan Area
# Experience
# Bloomberg LP
# Senior Software Developer
# August 2022 - Present (3 years)
# New York City Metropolitan Area
# Bloomberg Trading and Analytics - Asset and Investment Manager (AIM)
# Automation Frameworks
# Dell
# Software Developer In Test
# October 2017 - August 2022 (4 years 11 months)
# Austin, Texas
# • Incorporating test automation frameworks for designing and programming
# test automation scripts
# • Investigating problems with QA analysts and software developers to find
# solutions in software and
# hardware as a result of testing
# • Coordinating with product management and software and support engineers
# to deliver stable
# enterprise software products.
# • Analyzing and verifying optimal automated and manual test approaches and
# executing acceptance, integration, installation and system testing.
# Dell
# Software Validation Intern
# May 2017 - August 2017 (4 months)
# Round Rock, TX
# • Experience with multiple release cycles, with focus on test strategies,
# test frameworks, test plans, and execution of test cases. • Expertise of Design
# and implementation of the REST API • Workings of Atlassian, Jira, Qmetry
# quality assurance standards   • Test Automation for Android Applications on
# Android Studio
#   Page 1 of 3
# CSC 305 Software Engineering
# Teaching Assistant
# January 2017 - May 2017 (5 months)
# University Of Rhode Island
# • Reinforcing lectures, reviewing material one-on-one or in small groups
# • Creating an interactive environment for the students to learn the software
# development life cycle and it’s intricacies
# • Assisting Professor with grading, record-keeping and attendance
# URI Computer Science Department
# Lab Manager / Technician
# January 2016 - May 2017 (1 year 5 months)
# University Of Rhode Island
# • Collaboration with faculty to conigure CS Laboratories
# • Computer lab maintenance; IT Work, Network Manager
# • Troubleshooting of MAC OS ,Windows and linux systems
# • Re-imaging, Restoring, mirroring over 60 computers
# • Working remotely through servers to control and solve network problems
# from anywhere at anytime.
# • Lab manager paperwork ; Payroll approval (timesheets), scheduling hours for
# lab monitors, and hiring new staff
# URI Technology and Media Services
# Network Consultant
# January 2016 - December 2016 (1 year)
# University Of Rhode Island
# • Assess and resolve user problems involving multiple platforms and
# architectures
# • Provide support for Macintosh and PC hardware, networking, printing, and
# interface issues
# • Provide solutions to concerns regarding use of standard desktop software,
# including system, utility, security, web browsing, antivirus, and office
# productivity software.
# • Desktop and mobile email client configuration
# URI Foundation
# Student Ambassador
# August 2015 - January 2016 (6 months)
# Uri Foundation
#   Page 2 of 3
# • Contact alumni of Stetson to educate them on the importance of the
# Annual Fund.
# • Establish a positive rapport with the alumni you call.
# • Respond positively to problems and answer any questions about the
# University.
# • Request a gift to the Annual Fund. If necessary, negotiate the pledge
# amount.
# • Update address and employment of all alumni contacts.
# • Maintain records of each evening’s calls.
# • Follow all other procedures and guideline in the training manual.
# • Keep all donor information confidential. Forms should not be discussed
# among callers or outside of the building.
# Department of Housing and Residential Life
# Resident Assistant
# August 2014 - December 2014 (5 months)
# Heathman Hall, URI
# Collaborate with other Peer Leaders, staff and faculty in creating a welcoming
# and inclusive campus community
# Provide resources and opportunities for students to pursue and reflect on
# experiences that prepare students for their post Carleton lives
# Serve as a positive role model and mentor to students
# Encourage students to explore and become involved in a variety of curricular
# and co-curricular activities on campus and in the community
# Be a positive source of energy and information to students
# Be available to assist with the welcoming of students and their families during
# New Student Week
# Serve as an effective participant in small group settings during New Student
# Week
# Education
# University of Rhode Island
# Bachelor of Science (B.S.) Computer Science, Computer
# Science · (2013 - 2017)
# University of Rhode Island
# Bachelor of Science (B.S.), Computer Science · (2013 - 2017)
#   Page 3 of 3

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Araiz Baqi"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Araiz Baqi. You are answering questions on Araiz Baqi's website, particularly questions related to Araiz Baqi's career, background, skills and experience. Your responsibility is to represent Araiz Baqi for interactions on the website as faithfully as possible. You are given a summary of Araiz Baqi's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Araiz Baqi. I'm a software engineer and have been in the industry for 8 years. I've had an AI and ML focus throughout my career which as of late I have been really pushing. \nAI work in my day job: At Dell, I was one of the inventors of a Log analysis tool that detected anomolies using the k-nearest neighbours algorigthm on a vector database of test case result data. At Bloomberg, I'm spearheaded a project that brings AI to the world of BDD testing. \nI'm originally from Islamabad, Pakistan but have been in the US for 12 years now - 4 years of education pursing a BS in computer science at the university of rhode island, then working as a test automation engineer and SDET at dell, and finally a senior software engineer at bloomberg.\n\nI love food, staying fit, yoga, cats.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\n7813534440 (Mobile)\naraiz.baqi@gmail.com\nwww.linkedin.com/in/araizbaqi\n(LinkedIn)\nTop Skills\nComputer Proficiency\nLeadership\nNetwork Proficiency\nLanguages\nHindi (Full Professional)\nUrdu (Native or Bilingual)\nIntroductory Italian (Elementary)\nEnglish (Full Professional)\nCertifications\nHigh School degree\nPublications\nSoccer Analyst / Writer\nAraiz Baqi\nSenior Software Developer\nNew York City Metropolitan Area\nExperience\nBloomberg LP\nSenior Software Developer\nAugust 2022\xa0-\xa0Present\xa0(3 years)\nNew York City Metropolitan Area\nBloomberg Trading and Analytics - Asset and Investment Manager (AIM)\nAutomation Frameworks \nDell\nSoftware Developer In Test\nOctober 2017\xa0-\xa0August 2022\xa0(4 years 11 months)\nAustin, Texas\n• Incorporating test automation frameworks for designing and programming\ntest automation scripts \n• Investigating problems with QA analysts and software developers to find\nsolutions in software and \nhardware as a result of testing\n• Coordinating with product management and software and support engineers\nto deliver stable \nenterprise software products.\n• Analyzing and verifying optimal automated and manual test approaches and\nexecuting acceptance, integration, installation and system testing.\nDell\nSoftware Validation Intern\nMay 2017\xa0-\xa0August 2017\xa0(4 months)\nRound Rock, TX\n• Experience with multiple release cycles, with focus on test strategies,\ntest frameworks, test plans, and execution of test cases. • Expertise of Design\nand implementation of the REST API • Workings of Atlassian, Jira, Qmetry\nquality assurance standards   • Test Automation for Android Applications on\nAndroid Studio\n\xa0 Page 1 of 3\xa0 \xa0\nCSC 305 Software Engineering\nTeaching Assistant\nJanuary 2017\xa0-\xa0May 2017\xa0(5 months)\nUniversity Of Rhode Island\n• Reinforcing lectures, reviewing material one-on-one or in small groups \n• Creating an interactive environment for the students to learn the software\ndevelopment life cycle and it’s intricacies\n• Assisting Professor with grading, record-keeping and attendance\nURI Computer Science Department\nLab Manager / Technician\nJanuary 2016\xa0-\xa0May 2017\xa0(1 year 5 months)\nUniversity Of Rhode Island\n• Collaboration with faculty to conigure CS Laboratories\n• Computer lab maintenance; IT Work, Network Manager\n• Troubleshooting of MAC OS ,Windows and linux systems\n• Re-imaging, Restoring, mirroring over 60 computers\n• Working remotely through servers to control and solve network problems\nfrom anywhere at anytime.\n• Lab manager paperwork ; Payroll approval  ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'Yes, I am one of the inventors of a log analysis tool that detects anomalies using the k-nearest neighbors algorithm on a vector database of test case result data during my time at Dell. This work contributed to the development of a patent in the AI domain, which showcases my focus and expertise in artificial intelligence and machine learning. If you have any more questions about my work or experience, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The response is excellent. It concisely answers the question and accurately reflects the information provided in the context. It also maintains a professional and engaging tone, consistent with the instructions.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# This is unacceptable. The agent is using pig latin, which is unprofessional and doesn't follow instructions.
# Passed evaluation - returning reply
